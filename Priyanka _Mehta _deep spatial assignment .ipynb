# %% [markdown]
# # Exploratory data analysis

# %%
# IMPORTING THE LIBRARIES

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns

# %%
data = pd.read_csv("C:\\Users\\priyanka\\Anaconda3\\Lib\\site-packages\\pandas\\io\\Data_MFR_310.csv") #loading the dataset

# %%
dataset=data.copy()

# %% [markdown]
# # Data Preprocessing

# %%
dataset.head(10)
# Out:
#          Unnamed: 0  513FC31103.pv  513HC31114-5.mv  513PC31201.pv  \
# 0  04-05-2018 19:45      24856.584            0.153      30.414835
# 1  04-05-2018 21:45      25537.250            0.153      30.527121
# 2  04-05-2018 23:45      25689.266            0.153      30.356180
# 3  04-06-2018 01:45      25098.754            0.153      30.894308
# 4  04-06-2018 03:45      24853.941            0.150      30.680647
# 5  04-06-2018 05:45      25362.809            0.150      30.438940
# 6  04-06-2018 07:45      25642.936            0.150      30.419355
# 7  04-06-2018 09:45      27009.320            0.150      30.504484
# 8  04-06-2018 11:45      27971.072            0.150            NaN
# 9  04-06-2018 13:45      27307.461            0.150      30.204451
#
#    513LC31202.pv  513FC31409.pv  513FC31114-5.pv  513TC31220.pv  MFR
# 0      79.657906      50850.578         0.163994      80.399605  3.4
# 1      78.532608      42229.813         0.129739      78.861328  3.2
# ...

# %%
dataset.shape
# Out:
# (2564, 9)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2564 entries, 0 to 2563
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       2564 non-null   object
#  1   513FC31103.pv    2486 non-null   float64
#  2   513HC31114-5.mv  2560 non-null   float64
#  3   513PC31201.pv    2484 non-null   float64
#  4   513LC31202.pv    2484 non-null   float64
#  5   513FC31409.pv    2484 non-null   float64
#  6   513FC31114-5.pv  2486 non-null   float64
#  7   513TC31220.pv    2484 non-null   float64
#  8   MFR              2564 non-null   float64
# dtypes: float64(8), object(1)
# memory usage: 180.4+ KB

# %%
dataset.columns
# Out:
# Index(['Unnamed: 0', '513FC31103.pv', '513HC31114-5.mv', '513PC31201.pv',
#        '513LC31202.pv', '513FC31409.pv', '513FC31114-5.pv', '513TC31220.pv',
#        'MFR'],
#       dtype='object')

# %% [markdown]
# # Finding NULL values and replacing them with the mean

# %%
#1 column
dataset['Unnamed: 0'].isnull().sum()
# Out:
# 0

# %%
dataset['Time']=dataset['Unnamed: 0']

# %%
#2nd column
dataset['513FC31103.pv'].isnull().sum()
# Out:
# 78

# %%
dataset['513FC31103.pv'].mean()
# Out:
# 25306.285728881736

# %%
dataset['Propylene flow']=dataset['513FC31103.pv'].replace(np.nan,dataset['513FC31103.pv'].mean())

# %%
dataset['Propylene flow'].head(10)
# Out:
# 0    24856.584
# 1    25537.250
# 2    25689.266
# 3    25098.754
# 4    24853.941
# 5    25362.809
# 6    25642.936
# 7    27009.320
# 8    27971.072
# 9    27307.461
# Name: Propylene flow, dtype: float64

# %%
#3rd column
dataset['513HC31114-5.mv'].isnull().sum()
# Out:
# 4

# %%
dataset['513HC31114-5.mv'].mean()
# Out:
# 0.17842734383007813

# %%
dataset['Hydrogen ratio']=dataset['513HC31114-5.mv'].replace(np.nan,dataset['513HC31114-5.mv'].mean())

# %%
dataset['Hydrogen ratio'].head(10)
# Out:
# 0    0.153
# 1    0.153
# 2    0.153
# 3    0.153
# 4    0.150
# 5    0.150
# 6    0.150
# 7    0.150
# 8    0.150
# 9    0.150
# Name: Hydrogen ratio, dtype: float64

# %%
#4th column
dataset['513PC31201.pv'].isnull().sum()
# Out:
# 80

# %%
dataset['513PC31201.pv'].mean()
# Out:
# 30.66370562278583

# %%
dataset['Pressure controller']=dataset['513PC31201.pv'].replace(np.nan,dataset['513PC31201.pv'].mean())

# %%
dataset['Pressure controller'].head(10)
# Out:
# 0    30.414835
# 1    30.527121
# 2    30.356180
# 3    30.894308
# 4    30.680647
# 5    30.438940
# 6    30.419355
# 7    30.504484
# 8    30.663706
# 9    30.204451
# Name: Pressure controller, dtype: float64

# %%
#5th column

dataset['513LC31202.pv'].isnull().sum()
# Out:
# 80

# %%
dataset['513LC31202.pv'].mean()
# Out:
# 77.6510551441224

# %%
dataset['Level controller']=dataset['513LC31202.pv'].replace(np.nan,dataset['513LC31202.pv'].mean())

# %%
dataset['Level controller'].head(10)
# Out:
# 0    79.657906
# 1    78.532608
# 2    78.842636
# 3    79.173500
# 4    78.677299
# 5    78.293411
# 6    78.568573
# 7    78.852005
# 8    77.651055
# 9    78.931427
# Name: Level controller, dtype: float64

# %%
#6th column
dataset['513FC31409.pv'].isnull().sum()
# Out:
# 80

# %%
dataset['513FC31409.pv'].mean()
# Out:
# 42525.14000032206

# %%
dataset['Liquefied Recycle gas']=dataset['513FC31409.pv'].replace(np.nan,dataset['513FC31409.pv'].mean())

# %%
dataset['Liquefied Recycle gas'].head(10)
# Out:
# 0    50850.578
# 1    42229.813
# 2    45335.852
# 3    43077.016
# 4    40404.387
# 5    32548.566
# 6    42557.902
# 7    45878.480
# 8    42525.140
# 9    49528.848
# Name: Liquefied Recycle gas, dtype: float64

# %%
#7th column
dataset['513FC31114-5.pv'].isnull().sum()
# Out:
# 78

# %%
dataset['513FC31114-5.pv'].mean()
# Out:
# 0.13853018163354786

# %%
dataset['Hydrogen Flow']=dataset['513FC31114-5.pv'].replace(np.nan,dataset['513FC31114-5.pv'].mean())

# %%
dataset['Hydrogen Flow'].head(10)
# Out:
# 0    0.163994
# 1    0.129739
# 2    0.150003
# 3    0.151543
# 4    0.122582
# 5    0.140550
# 6    0.166875
# 7    0.160510
# 8    0.150164
# 9    0.159013
# Name: Hydrogen Flow, dtype: float64

# %%
# 8th column
dataset['513TC31220.pv'].isnull().sum()
# Out:
# 80

# %%
dataset['513TC31220.pv'].mean()
# Out:
# 80.14436506280194

# %%
dataset['Temperature controller']=dataset['513TC31220.pv'].replace(np.nan,dataset['513TC31220.pv'].mean())

# %%
dataset['Temperature controller'].head(10)
# Out:
# 0    80.399605
# 1    78.861328
# 2    78.818115
# 3    79.022720
# 4    79.038483
# 5    79.061462
# 6    79.565430
# 7    79.390396
# 8    80.144365
# 9    78.511749
# Name: Temperature controller, dtype: float64

# %%
# 9th column
dataset['MFR'].isnull().sum()
# Out:
# 0

# %%
dataset['MFR']=dataset['MFR']

# %%
dataset.drop(['Unnamed: 0', '513FC31103.pv', '513HC31114-5.mv', '513PC31201.pv',
              '513LC31202.pv', '513FC31409.pv', '513FC31114-5.pv', '513TC31220.pv'],axis=1,inplace=True)

# %%
dataset.head()
# Out:
#    MFR              Time  Propylene flow  Hydrogen ratio  Pressure controller  \
# 0  3.4  04-05-2018 19:45       24856.584           0.153            30.414835
# 1  3.2  04-05-2018 21:45       25537.250           0.153            30.527121
# 2  3.2  04-05-2018 23:45       25689.266           0.153            30.356180
# 3  3.1  04-06-2018 01:45       25098.754           0.153            30.894308
# 4  3.3  04-06-2018 03:45       24853.941           0.150            30.680647
#
#    Level controller  Liquefied Recycle gas  Hydrogen Flow  \
# 0         79.657906              50850.578       0.163994
# 1         78.532608              42229.813       0.129739
# 2         78.842636              45335.852       0.150003
# 3         79.173500              43077.016       0.151543
# 4         78.677299              40404.387       0.122582
#
#    Temperature controller
# 0               80.399605
# 1               78.861328
# 2               78.818115
# 3               79.022720
# ...

# %%
dataset.columns
# Out:
# Index(['MFR', 'Time', 'Propylene flow', 'Hydrogen ratio',
#        'Pressure controller', 'Level controller', 'Liquefied Recycle gas',
#        'Hydrogen Flow', 'Temperature controller'],
#       dtype='object')

# %%
dataset=dataset[['Time', 'Propylene flow', 'Hydrogen ratio',
       'Pressure controller', 'Level controller', 'Liquefied Recycle gas',
       'Hydrogen Flow', 'Temperature controller','MFR']]

# %%
dataset.head()
# Out:
#                Time  Propylene flow  Hydrogen ratio  Pressure controller  \
# 0  04-05-2018 19:45       24856.584           0.153            30.414835
# 1  04-05-2018 21:45       25537.250           0.153            30.527121
# 2  04-05-2018 23:45       25689.266           0.153            30.356180
# 3  04-06-2018 01:45       25098.754           0.153            30.894308
# 4  04-06-2018 03:45       24853.941           0.150            30.680647
#
#    Level controller  Liquefied Recycle gas  Hydrogen Flow  \
# 0         79.657906              50850.578       0.163994
# 1         78.532608              42229.813       0.129739
# 2         78.842636              45335.852       0.150003
# 3         79.173500              43077.016       0.151543
# 4         78.677299              40404.387       0.122582
#
#    Temperature controller  MFR
# 0               80.399605  3.4
# 1               78.861328  3.2
# 2               78.818115  3.2
# 3               79.022720  3.1
# ...

# %%
dataset['MFR'].mean()
# Out:
# 8.18521840873635

# %%
dataset.describe()#statstical description of data
# Out:
#        Propylene flow  Hydrogen ratio  Pressure controller  Level controller  \
# count     2564.000000     2564.000000          2564.000000       2564.000000
# mean     25306.285729        0.178427            30.663706         77.651055
# std       1680.314293        0.077412             0.416686          0.905134
# min      16106.025000        0.000000            26.946344         74.575958
# 25%      24407.781250        0.136000            30.450446         77.001868
# 50%      25306.285729        0.174000            30.633575         77.557159
# 75%      26372.165750        0.200000            30.914744         78.191603
# max      30083.688000        0.980000            32.674332         83.841675
#
#        Liquefied Recycle gas  Hydrogen Flow  Temperature controller  \
# count            2564.000000    2564.000000             2564.000000
# mean            42525.140000       0.138530               80.144365
# std             11153.613741       0.041227                0.810599
# ...

# %%
plt.figure(figsize = (20,5))

sns.countplot(x='MFR',data=dataset)

# %%
plt.figure(figsize = (20,5))

sns.countplot(x='Hydrogen Flow',data=dataset)

# %% [markdown]
# Hydrogen flow is equal for all

# %%
plt.figure(figsize = (20,5))

sns.countplot(x="Liquefied Recycle gas",data=dataset)

# %%
plt.figure(figsize = (20,5))

sns.countplot(x="Hydrogen ratio",data=dataset)

# %% [markdown]
# Hydrogen ratio is having higher imapct on the middle range of the MFG

# %%
plt.figure(figsize=(10,6))
cor = dataset.corr()
sns.heatmap(cor, annot=True,cmap='Blues')
plt.show()

# %% [markdown]
# Here,we can see Hydrogen ratio ,pressure controller is highly coorelated with MFR

# %%
#histrogram displaying the distribution of  MFR
plt.figure(figsize = (20,5))

dataset['MFR'].hist(bins=30)

# %% [markdown]
# MFR values lies maximum in the range between 1-5

# %%
# get columns to plot
plt.figure(figsize=(10,10))

columns = dataset.columns.drop(['MFR','Time'])
# create x data
x_data = range(0,dataset.shape[0])
# create figure and axis
fig, ax = plt.subplots()
# plot each column
for column in columns:
    ax.plot(x_data, dataset[column], label=column)
# set title and legend
ax.set_title('Prediction of Polymer Quality')
ax.legend()

# %% [markdown]
# Liquified recycle gas and propyline flow is more working in predicting the polymer quality

# %% [markdown]
# ## Data Visulaization and relation between each and every feature(including the target value)

# %%
#Data Visulaization and relation between each and every feature(including the target value)
import seaborn as sns
sns.pairplot(dataset)

# %% [markdown]
# # Scatter plot to find the relational graph with some features and the target value

# %%
y = dataset["MFR"] 
x = dataset["Hydrogen ratio"] 
plt.scatter(x, y, label= "stars", color= "m", marker= "*", s=30) 
# x-axis label 
plt.ylabel('MFR') 
# frequency label 
plt.xlabel('Hydrogen ratio') 
# function to show the plot 
plt.show()

# %% [markdown]
# This plot shows the maximum MFR values for the polymer lies in lower range for the hydrogen ratio.

# %%
y = dataset["MFR"] 
x = dataset["Pressure controller"] 
plt.scatter(x, y, label= "stars", color= "orange", marker= "*", s=30) 
# x-axis label 
plt.ylabel('MFR') 
# frequency label 
plt.xlabel('Pressure controller') 
# function to show the plot 
plt.show()

# %% [markdown]
# This  Plot shows that the MFR of the polymer is MOST Occuring in the range between 30-32 of the Pressure controller

# %% [markdown]
# # Feature Importance

# %%
X = dataset.drop(['MFR','Time'], axis = 1)  # INDEPENDENT VARIABLES

# %%
X.head()
# Out:
#    Propylene flow  Hydrogen ratio  Pressure controller  Level controller  \
# 0       24856.584           0.153            30.414835         79.657906
# 1       25537.250           0.153            30.527121         78.532608
# 2       25689.266           0.153            30.356180         78.842636
# 3       25098.754           0.153            30.894308         79.173500
# 4       24853.941           0.150            30.680647         78.677299
#
#    Liquefied Recycle gas  Hydrogen Flow  Temperature controller
# 0              50850.578       0.163994               80.399605
# 1              42229.813       0.129739               78.861328
# 2              45335.852       0.150003               78.818115
# 3              43077.016       0.151543               79.022720
# 4              40404.387       0.122582               79.038483

# %%
y=dataset['MFR']
y.head()
# Out:
# 0    3.4
# 1    3.2
# 2    3.2
# 3    3.1
# 4    3.3
# Name: MFR, dtype: float64

# %%
from sklearn.ensemble import ExtraTreesClassifier
import matplotlib.pyplot as plt
model = ExtraTreesClassifier()
model.fit(X,y.astype(int))
print(model.feature_importances_) #use inbuilt class feature_importances of tree based classifiers
#plot graph of feature importances for better visualization
feat_importances = pd.Series(model.feature_importances_, index=X.columns)
feat_importances.nlargest(10).plot(kind='barh')
plt.show()
# Out:
# [0.1338652  0.17305496 0.16288619 0.12271436 0.13342658 0.14248937
#  0.13156334]

# %% [markdown]
# From this plot,We know now that, Hydrogen ratio and Pressure controller is highly responsible for MFR of the Polymer
# and Level controller is least and Liquefied Recycle gas,Hydrogen Flow,Temperature controller and propylene flow are almost equally responsible

# %%
from sklearn.preprocessing import  StandardScaler
sc=StandardScaler()
X=sc.fit_transform(X)

# %%
X
# Out:
# array([[-2.67681738e-01, -3.28530873e-01, -5.97378458e-01, ...,
#          7.46579736e-01,  6.17779433e-01,  3.14939519e-01],
#        [ 1.37479830e-01, -3.28530873e-01, -3.27851920e-01, ...,
#         -2.64833098e-02, -2.13268561e-01, -1.58313421e+00],
#        [ 2.27966267e-01, -3.28530873e-01, -7.38171426e-01, ...,
#          2.52049276e-01,  2.78333586e-01, -1.63645455e+00],
#        ...,
#        [ 0.00000000e+00,  3.58612506e-16, -8.52778282e-15, ...,
#          0.00000000e+00, -6.73368118e-16,  1.75347158e-14],
#        [ 0.00000000e+00,  3.58612506e-16, -8.52778282e-15, ...,
#          0.00000000e+00, -6.73368118e-16,  1.75347158e-14],
#        [ 0.00000000e+00, -2.30534858e+00, -8.52778282e-15, ...,
#          0.00000000e+00, -6.73368118e-16,  1.75347158e-14]])

# %%
y
# Out:
# 0        3.4
# 1        3.2
# 2        3.2
# 3        3.1
# 4        3.3
#         ...
# 2559    12.3
# 2560     3.5
# 2561     4.0
# 2562     3.7
# 2563     3.4
# Name: MFR, Length: 2564, dtype: float64

# %% [markdown]
# # Splitting the dataset

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y.astype(int), test_size = 0.3)

# %% [markdown]
# # Applying Different Machine Learning Algorithms

# %% [markdown]
# # Decision Tree

# %%
from sklearn import tree
D_model=tree.DecisionTreeRegressor()
D_model.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=None,
#                       max_features=None, max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, presort='deprecated',
#                       random_state=None, splitter='best')

# %%
#For Decision Tree
y_pred=D_model.predict(X_test)
print("Model r2_score is :",metrics.r2_score(y_test,y_pred))
# Out:
# Model r2_score is : 0.5191285123870846

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor
model=RandomForestRegressor(n_estimators=1000)
model.fit(X_train,y_train)
# Out:
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=1000, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False)

# %%
from sklearn import metrics
y_pred=model.predict(X_test)
print("Model r2_score is :",metrics.r2_score(y_test,y_pred))
# Out:
# Model r2_score is : 0.6989230762985836

# %% [markdown]
# # Support Vector Regressor

# %%
# Fitting SVR to the dataset
from sklearn.svm import SVR
regressor = SVR(kernel = 'rbf')
regressor.fit(X_train, y_train)
# Out:
# SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='scale',
#     kernel='rbf', max_iter=-1, shrinking=True, tol=0.001, verbose=False)

# %%
# Predicting a new result
y_pred = regressor.predict(X_test)
print("Model r2_score is :",metrics.r2_score(y_test,y_pred))
# Out:
# Model r2_score is : 0.6413361625775054

# %% [markdown]
# # XGBOOST

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y.astype(int), test_size = 0.2)

# %%
from xgboost import XGBRegressor
regressor=XGBRegressor()
regressor.fit(X_train,y_train)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#              importance_type='gain', interaction_constraints='',
#              learning_rate=0.300000012, max_delta_step=0, max_depth=6,
#              min_child_weight=1, missing=nan, monotone_constraints='()',
#              n_estimators=100, n_jobs=0, num_parallel_tree=1,
#              objective='reg:squarederror', random_state=0, reg_alpha=0,
#              reg_lambda=1, scale_pos_weight=1, subsample=1, tree_method='exact',
#              validate_parameters=1, verbosity=None)

# %%
y_pred=regressor.predict(X_test)

# %%
print("Model r2_score is :",metrics.r2_score(y_test,y_pred))
# Out:
# Model r2_score is : 0.5955050686058894

# %% [markdown]
# # Hyperparameter optimization using XGBoost

# %%
import xgboost
classifier=xgboost.XGBRegressor()

# %%
import xgboost
regressor=xgboost.XGBRegressor()

# %%
booster=['gbtree','gblinear']
base_score=[0.25,0.5,0.75,1]

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
## Hyper Parameter Optimization


n_estimators = [100, 500, 900, 1100, 1500]
max_depth = [2, 3, 5, 10, 15]
booster=['gbtree','gblinear']
learning_rate=[0.05,0.1,0.15,0.20]
min_child_weight=[1,2,3,4]

# Define the grid of hyperparameters to search
hyperparameter_grid = {
    'n_estimators': n_estimators,
    'max_depth':max_depth,
    'learning_rate':learning_rate,
    'min_child_weight':min_child_weight,
    'booster':booster,
    'base_score':base_score
    }

# %%
random_cv = RandomizedSearchCV(estimator=regressor,
            param_distributions=hyperparameter_grid,
            cv=5, n_iter=50,
            scoring = 'neg_mean_absolute_error',n_jobs = 4,
            verbose = 5, 
            return_train_score = True,
            random_state=42)

# %%
random_cv.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  10 tasks      | elapsed:   12.1s
# [Parallel(n_jobs=4)]: Done  64 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=4)]: Done 154 tasks      | elapsed:  2.7min
# [Parallel(n_jobs=4)]: Done 250 out of 250 | elapsed:  3.6min finished
# RandomizedSearchCV(cv=5, error_score=nan,
#                    estimator=XGBRegressor(base_score=None, booster=None,
#                                           colsample_bylevel=None,
#                                           colsample_bynode=None,
#                                           colsample_bytree=None, gamma=None,
#                                           gpu_id=None, importance_type='gain',
#                                           interaction_constraints=None,
#                                           learning_rate=None,
# ...

# %%
random_cv.best_estimator_
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#              importance_type='gain', interaction_constraints='',
#              learning_rate=0.05, max_delta_step=0, max_depth=15,
#              min_child_weight=4, missing=nan, monotone_constraints='()',
#              n_estimators=900, n_jobs=0, num_parallel_tree=1,
#              objective='reg:squarederror', random_state=0, reg_alpha=0,
#              reg_lambda=1, scale_pos_weight=1, subsample=1, tree_method='exact',
#              validate_parameters=1, verbosity=None)

# %%
regressor=xgboost.XGBRegressor(base_score=0.25, booster='gbtree', colsample_bylevel=1,
       colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
       max_depth=2, min_child_weight=1, missing=None, n_estimators=900,
       n_jobs=1, nthread=None, objective='reg:linear', random_state=0,
       reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
       silent=True, subsample=1)

# %%
regressor.fit(X_train,y_train)
# Out:
# [09:53:02] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.1.0/src/objective/regression_obj.cu:168: reg:linear is now deprecated in favor of reg:squarederror.
# [09:53:02] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [09:53:06] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.1.0/src/objective/regression_obj.cu:168: reg:linear is now deprecated in favor of reg:squarederror.
# XGBRegressor(base_score=0.25, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#              importance_type='gain', interaction_constraints='',
# ...

# %%
y_pred=regressor.predict(X_test)

# %%
print("Model r2_score is :",metrics.r2_score(y_test,y_pred))
# Out:
# Model r2_score is : 0.6596918763554035

# %% [markdown]
#  From the above We can see that Random forest is providing us the  better R2_score

# %% [markdown]
# XGboost is also providing better R2_Score after  performing Hyperparameter optimization
